# %% [markdown]
# <a href="https://colab.research.google.com/github/mathiastadtlober-max/trabalho_fernando_posser/blob/main/TRABALHO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # importa o pandas e dá um apelido a ele

dados = pd.read_csv("dados.csv") # carregando um csv com o delimitador ;

dados #mostrando na tela
# Out:
#     Carimbo de data/hora               Endereço de e-mail  \
# 0    19/06/2025 00:04:14            nikali.hoje@gmail.com
# 1    21/06/2025 17:21:56           liztomazelli@gmail.com
# 2    21/06/2025 17:25:04        alanisdiscord12@gmail.com
# 3    21/06/2025 17:36:45     leonardomaziero160@gmail.com
# 4    21/06/2025 17:44:08             ngcdaddy14@gmail.com
# ..                   ...                              ...
# 97   25/06/2025 16:24:21      bordignonandrieli@gmail.com
# 98   25/06/2025 16:35:24  davi.mendes@sounotredame.org.br
# 99   25/06/2025 16:37:31           feijao280986@gmail.com
# 100  25/06/2025 16:39:17           davimiguelwm@gmail.com
# 101  25/06/2025 16:46:34   biancavitoriademoura@gmail.com
#
#     Você aposta ou já apostou em jogos de azar? Qual é a sua idade?  \
# 0                                           Não                 NaN
# 1                                           Não                 NaN
# ...

# %%
dados.head() # mostra só as 5 primeiras linhas
# Out:
#   Carimbo de data/hora            Endereço de e-mail  \
# 0  19/06/2025 00:04:14         nikali.hoje@gmail.com
# 1  21/06/2025 17:21:56        liztomazelli@gmail.com
# 2  21/06/2025 17:25:04     alanisdiscord12@gmail.com
# 3  21/06/2025 17:36:45  leonardomaziero160@gmail.com
# 4  21/06/2025 17:44:08          ngcdaddy14@gmail.com
#
#   Você aposta ou já apostou em jogos de azar? Qual é a sua idade?  \
# 0                                         Não                 NaN
# 1                                         Não                 NaN
# 2                                         Não                 NaN
# 3                                         Sim       17 ou 18 anos
# 4                                         Sim       19 ou 20 anos
#
#   Qual seu gênero? Qual é o seu nível de escolaridade?  \
# 0              NaN                                 NaN
# 1              NaN                                 NaN
# 2              NaN                                 NaN
# ...

# %%
# mostrar os nomes das colunas
dados.columns
# Out:
# Index(['Carimbo de data/hora', 'Endereço de e-mail',
#        'Você aposta ou já apostou em jogos de azar?', 'Qual é a sua idade?',
#        'Qual seu gênero?', 'Qual é o seu nível de escolaridade?',
#        'Quantas pessoas, contando com você, moram em sua casa?',
#        'Qual classe social você pertence?', 'O que é um orçamento pessoal?',
#        'Qual dessas opções é considerada uma boa prática financeira?',
#        'Qual é a principal vantagem de ter uma reserva de emergência?',
#        'O que significa "gastar menos do que se ganha"?',
#        '  Quais são suas fontes de renda atualmente?  ',
#        'Porque você começou a apostar?',
#        'Você concorda com a afirmação:\nMinhas apostas tem me dado lucro.',
#        'Você concorda com a afirmação:\nQuando fico no prejuízo, continuo apostando.',
#        'Com que frequência você aposta?'],
#       dtype='object')

# %%
# renomear uma coluna
dados.rename(columns={
    "Qual é o seu nível de escolaridade?": "escolaridade"},
    inplace=True
)
dados.head()
# Out:
#   Carimbo de data/hora            Endereço de e-mail  \
# 0  19/06/2025 00:04:14         nikali.hoje@gmail.com
# 1  21/06/2025 17:21:56        liztomazelli@gmail.com
# 2  21/06/2025 17:25:04     alanisdiscord12@gmail.com
# 3  21/06/2025 17:36:45  leonardomaziero160@gmail.com
# 4  21/06/2025 17:44:08          ngcdaddy14@gmail.com
#
#   Você aposta ou já apostou em jogos de azar? Qual é a sua idade?  \
# 0                                         Não                 NaN
# 1                                         Não                 NaN
# 2                                         Não                 NaN
# 3                                         Sim       17 ou 18 anos
# 4                                         Sim       19 ou 20 anos
#
#   Qual seu gênero?                escolaridade  \
# 0              NaN                         NaN
# 1              NaN                         NaN
# 2              NaN                         NaN
# 3  Homem cisgênero       Ensino Médio Completo
# ...

# %%
dados.info() # trás informações gerais sobre cada coluna
# object: string
# int64: inteiro (-10,2,50,1000...)
# float64: ponto flutuante (1.8, 22.345623, -50.30...)
# bool: booleano (True, False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 17 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Carimbo de data/hora                                                         102 non-null    object
#  1   Endereço de e-mail                                                           102 non-null    object
#  2   Você aposta ou já apostou em jogos de azar?                                  102 non-null    object
#  3   Qual é a sua idade?                                                          52 non-null     object
#  4   Qual seu gênero?                                                             51 non-null     object
#  5   escolaridade                                                                 51 non-null     object
# ...

# %%
# criar uma coluna booleana

# acessando a coluna "escolaridade"
dados.escolaridade
# Out:
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                          Ensino Médio Completo
# 4                     Ensino Superior Incompleto
#                          ...
# 97                                           NaN
# 98                                           NaN
# 99                                           NaN
# 100                                          NaN
# 101    Pós-graduação (especialização) incompleta
# Name: escolaridade, Length: 102, dtype: object

# %%
comparacao_escolaridade_frequencia = pd.crosstab(dados['escolaridade'], dados['Com que frequência você aposta?'])
display(comparacao_escolaridade_frequencia)
# Out:
# Com que frequência você aposta?            Apostei poucas vezes na vida  \
# escolaridade
# Ensino Médio Completo                                                 9
# Ensino Médio Incompleto                                               1
# Ensino Superior Completo                                              3
# Ensino Superior Incompleto                                            9
# Pós-graduação (especialização) completa                               4
# Pós-graduação (especialização) incompleta                             1
#
# Com que frequência você aposta?            DIariamente  Mensalmente  \
# escolaridade
# Ensino Médio Completo                                2            1
# Ensino Médio Incompleto                              0            1
# Ensino Superior Completo                             1            2
# Ensino Superior Incompleto                           4            5
# Pós-graduação (especialização) completa              0            1
# ...
